# %% [markdown]
# # 🐼 Introducción a Pandas en Python
#
# Pandas es una de las librerías más populares de Python para **análisis y manipulación de datos**.
# Está construida sobre NumPy y proporciona estructuras de datos flexibles y eficientes, principalmente: Pandas Series y Pandas DataFrame

# %% [markdown]
# # Pandas Series

# %%
import pandas as pd

# %%
paises = pd.Series(['Argentina', 'Peru', 'Chile', 'Paraguay', 'Uruguay'])
paises
# Out:
# 0    Argentina
# 1         Peru
# 2        Chile
# 3     Paraguay
# 4      Uruguay
# dtype: object

# %%
type(paises)
# Out:
# pandas.core.series.Series

# %%
paises = pd.Series(['Perú','Chile','Colombia','Ecuador'],index=[1,3,5,7])
paises
# Out:
# 1        Perú
# 3       Chile
# 5    Colombia
# 7     Ecuador
# dtype: object

# %% [markdown]
# ## CREAMOS PANDAS SERIES DESDE UN DICCIONARIO

# %%
dict = {
    1:'Perú',
    2:'Chile',
    3:'Colombia',
    4:'Ecuador'
}
pd.Series(dict)
# Out:
# 1        Perú
# 2       Chile
# 3    Colombia
# 4     Ecuador
# dtype: object

# %% [markdown]
# # Pandas DATAFRAME

# %%
dict = {
    'pais':['Perú','Chile','Colombia','Ecuador'],
    'pbi':[183,170,160,150],
    'habitantes':[33,22,22,50]
}
df_paises = pd.DataFrame(dict,index=[1,7,10,30])
df_paises
# Out:
#         pais  pbi  habitantes
# 1       Perú  183          33
# 7      Chile  170          22
# 10  Colombia  160          22
# 30   Ecuador  150          50

# %%
df_paises.columns
# Out:
# Index(['pais', 'pbi', 'habitantes'], dtype='object')

# %%
df_paises.index
# Out:
# Index([1, 7, 10, 30], dtype='int64')
